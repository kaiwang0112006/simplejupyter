# %% [markdown]
# ## cluster heatmap

# %%
import mgkit.plots
import numpy
import pandas as pd
import seaborn as sns
import matplotlib.colors

# %matplotlib inline 
df = pd.read_csv('1.csv',index_col=[0])
df
# Out:
#             a         b         c         d         e         f
# sdf
# A    0.284518  0.256216  0.248780  0.707837  0.763918  0.281631
# B    0.041282  0.071024  0.561856  0.300916  0.852025  0.053506
# C    0.168025  0.719016  0.564571  0.760986  0.957404  0.638474
# D    0.626117  0.560230  0.725836  0.764701  0.096264  0.809124
# E    0.651383  0.051766  0.541925  0.039144  0.988917  0.102215
# F    1.000000  2.000000  2.000000  2.000000  3.000000  6.000000
# G    0.785062  0.340199  0.232549  0.586524  0.089960  0.321169
# H    0.668667  0.134342  0.215326  0.021484  0.254356  0.275358
# I    0.370684  0.283902  0.399806  0.440519  0.677640  0.032979
# J    4.000000  4.000000  4.000000  4.000000  4.000000  4.000000
# K    0.613143  0.545187  0.564929  0.545815  0.024863  0.205903
# L    0.541267  0.326272  0.405725  0.278790  0.217349  0.576312
# M    0.554812  0.542066  0.383639  0.586339  0.437751  0.256602
# N    0.705782  0.773749  0.769977  0.802034  0.383659  0.468235

# %%
import seaborn as sns
g = sns.clustermap(df)
